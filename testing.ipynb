# %%
print("Traceback (most recent call last):\n  File \"C:\\Users\\kuanjian\\Work\\TestingAPI\\flaskApp.py\", line 50, in getAISummary\n    return returnStringJsonContent(data), 200\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"C:\\Users\\kuanjian\\Work\\TestingAPI\\flaskApp.py\", line 13, in returnStringJsonContent\n    return json.dumps(json.dumps(content))\n                      ^^^^^^^^^^^^^^^^^^^\n  File \"C:\\Users\\kuanjian\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\json\\__init__.py\", line 231, in dumps\n    return _default_encoder.encode(obj)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"C:\\Users\\kuanjian\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\json\\encoder.py\", line 200, in encode\n    chunks = self.iterencode(o, _one_shot=True)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"C:\\Users\\kuanjian\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\json\\encoder.py\", line 258, in iterencode\n    return _iterencode(o, 0)\n           ^^^^^^^^^^^^^^^^^\n  File \"C:\\Users\\kuanjian\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\json\\encoder.py\", line 180, in default\n    raise TypeError(f'Object of type {o.__class__.__name__} '\nTypeError: Object of type Timestamp is not JSON serializable\n")
# Out:
# Traceback (most recent call last):
#   File "C:\Users\kuanjian\Work\TestingAPI\flaskApp.py", line 50, in getAISummary
#     return returnStringJsonContent(data), 200
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kuanjian\Work\TestingAPI\flaskApp.py", line 13, in returnStringJsonContent
#     return json.dumps(json.dumps(content))
#                       ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kuanjian\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py", line 231, in dumps
#     return _default_encoder.encode(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kuanjian\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kuanjian\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
# ...
